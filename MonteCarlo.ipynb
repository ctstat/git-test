# %%
import numpy as np 
import matplotlib.pyplot as plt 

x = 3.5 
size = 10000
np.random.seed(123)
errors = np.random.standard_normal(size = size)
xhat = x + errors

# %%
plt.hist(xhat)
plt.title(f'sample size = {size}')
plt.show()

# %%
print(np.mean(xhat))
# Out:
# 3.5097118922915955
